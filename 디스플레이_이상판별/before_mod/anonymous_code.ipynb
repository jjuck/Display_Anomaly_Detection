# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ## 1. 데이터 불러오기

# %% [markdown]
# ### 필수 라이브러리

# %%
import os
from pprint import pprint
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import xgboost as xgb
import shap

pd.set_option('display.max_columns', None)
pd.set_option('display.max_row', None)

# %%
# ROOT_DIR = "data"
# RANDOM_STATE = 110

# # CSV 파일 읽기
# X_Dam = pd.read_csv(os.path.join(ROOT_DIR, "Dam dispensing.csv"))
# X_AutoClave = pd.read_csv(os.path.join(ROOT_DIR, "Auto clave.csv"))
# X_Fill1 = pd.read_csv(os.path.join(ROOT_DIR, "Fill1 dispensing.csv"))
# X_Fill2 = pd.read_csv(os.path.join(ROOT_DIR, "Fill2 dispensing.csv"))

# # y 데이터 읽기
# y = pd.read_csv(os.path.join(ROOT_DIR, "train_y.csv"))

# %% [markdown]
# ### 데이터 병합
#
# x 데이터 병합

# %%
# # Rename columns
# X_Dam.columns = [i + " - Dam" for i in X_Dam.columns]
# X_AutoClave.columns = [i + " - AutoClave" for i in X_AutoClave.columns]
# X_Fill1.columns = [i + " - Fill1" for i in X_Fill1.columns]
# X_Fill2.columns = [i + " - Fill2" for i in X_Fill2.columns]
# X_Dam = X_Dam.rename(columns={"Set ID - Dam": "Set ID"})
# X_AutoClave = X_AutoClave.rename(columns={"Set ID - AutoClave": "Set ID"})
# X_Fill1 = X_Fill1.rename(columns={"Set ID - Fill1": "Set ID"})
# X_Fill2 = X_Fill2.rename(columns={"Set ID - Fill2": "Set ID"})

# # Merge X
# X = pd.merge(X_Dam, X_AutoClave, on="Set ID")
# X = pd.merge(X, X_Fill1, on="Set ID")
# X = pd.merge(X, X_Fill2, on="Set ID")
# X = X.drop(X[X.duplicated(subset="Set ID")].index).reset_index(drop=True)

# %%
# X.to_csv('X.csv')
# y.to_csv('y.csv')

# %%
ROOT_DIR = "data"
RANDOM_STATE = 110

X = pd.read_csv('X.csv', index_col=0).reset_index(drop=True)
y = pd.read_csv('y.csv', index_col=0).reset_index(drop=True)
# Out:
# Columns (63,65,245,247,279,281,410,412) have mixed types. Specify dtype option on import or set low_memory=False.

# %% [markdown]
# x 데이터와 y 데이터 병합

# %%
# Merge X and y
df_merged = pd.merge(X, y, "inner", on="Set ID")

# Drop columns with more than half of the values missing
drop_cols = []
for column in df_merged.columns:
    if (df_merged[column].notnull().sum() // 2) < df_merged[
        column
    ].isnull().sum():
        drop_cols.append(column)
df_merged = df_merged.drop(drop_cols, axis=1)

# Drop Lot ID
df_merged = df_merged.drop("LOT ID - Dam", axis=1)

# %%
# 결측치 피쳐 세 개의 피쳐가 결측치 수가 동일함
na_list = []
for i in df_merged.columns:
    if df_merged[i].isna().sum() > 0:
        na_list.append(i)
df_merged[na_list] = df_merged[na_list].fillna(0)

# %% [markdown]
# ## 2. 데이터 전처리

# %% [markdown]
# ### 언더 샘플링

# %%
normal_ratio = 1.0  # 1.0 means 1:1 ratio

df_normal = df_merged[df_merged["target"] == "Normal"]
df_abnormal = df_merged[df_merged["target"] == "AbNormal"]

num_normal = len(df_normal)
num_abnormal = len(df_abnormal)
print(f"  Total: Normal: {num_normal}, AbNormal: {num_abnormal}")

df_normal = df_normal.sample(
    n=int(num_abnormal * normal_ratio), replace=False, random_state=RANDOM_STATE
)
df_concat = pd.concat([df_normal, df_abnormal], axis=0).reset_index(drop=True)
df_concat.value_counts("target")
# Out:
#   Total: Normal: 38156, AbNormal: 2350
# target
# AbNormal    2350
# Normal      2350
# dtype: int64

# %% [markdown]
# ### 전처리 함수

# %%
import pandas as pd
import numpy as np

# 파트 1: 전처리 초기 단계
def preprocess_initial(df):
    # 고유값이 하나인 컬럼 찾기
    unique_value_1_columns = [column for column in df.columns if df[column].nunique() == 1]

    # 모든 행의 값이 다른 컬럼 찾기
    row_count = len(df)
    columns_to_check = ['Collect Date - Dam', 'Collect Date - Fill1', 'Collect Date - Fill2']
    matching_row_columns = [column for column in df.columns if df[column].value_counts().size == row_count]
    for col in columns_to_check:
        if col in matching_row_columns:
            matching_row_columns.remove(col)
        else:
            continue
    
    columns_to_convert = ['Collect Result.17 - Dam', 'Collect Result.7 - Fill1', 'Collect Result.17 - Fill2']
    for col in columns_to_convert:
        if col in df_columns:
            df_columns.remove(col)
        else:
            continue
        # 고유값, 혼합값 피쳐 제거
    df.drop(columns=unique_value_1_columns, inplace=True)
    df.drop(columns=matching_row_columns, inplace=True)
    return df

# # 파트 2: "OK" 값을 최빈값으로 대체하는 함수
# def replace_ok_with_mode(df):
#     # 최빈값으로 대체하는 함수
#     def replace_ok_with_mode_inner(df, columns):
#         for column in columns:
#             # 해당 컬럼의 최빈값 계산
#             mode_value = df[df[column] != 'OK'][column].astype(float).mode()[0]
#             # "OK" 값을 최빈값으로 대체
#             df[column] = df[column].replace('OK', mode_value)
#             df[column] = df[column].fillna(mode_value)
#         return df

#     # 대상 컬럼 리스트
#     columns_to_convert = ['Collect Result.17 - Dam', 'Collect Result.7 - Fill1', 'Collect Result.17 - Fill2']

#     # 함수 적용
#     df = replace_ok_with_mode_inner(df, columns_to_convert)
#     return df

# 파트 3: 날짜 데이터로 변환
def convert_to_datetime(df):
    df['Collect Date - Dam'] = pd.to_datetime(df['Collect Date - Dam'])
    df['Collect Date - AutoClave'] = pd.to_datetime(df['Collect Date - AutoClave'])
    df['Collect Date - Fill1'] = pd.to_datetime(df['Collect Date - Fill1'])
    df['Collect Date - Fill2'] = pd.to_datetime(df['Collect Date - Fill2'])
    return df

# 파트 4: 유사한 피쳐 제거
def reduce_dataframe(df):
    def get_value_counts_ratio(series):
        value_counts = series.value_counts(normalize=True)
        return value_counts.sort_values().values

    # 고유값 매핑 확인 함수
    def check_value_mapping(df, col1, col2):
        unique_values_1 = df[col1].unique()
        unique_values_2 = df[col2].unique()

        if len(unique_values_1) != len(unique_values_2):
            return False

        value_mapping = {}
        for val1 in unique_values_1:
            corresponding_values = df[df[col1] == val1][col2].unique()
            if len(corresponding_values) != 1:
                return False
            value_mapping[val1] = corresponding_values[0]

        for val1 in unique_values_1:
            if isinstance(val1, pd.Timestamp):
                ratio_1 = (df[col1].apply(lambda x: x.date() if isinstance(x, pd.Timestamp) else x) == val1.date()).mean()
                ratio_2 = (df[col2].apply(lambda x: x.date() if isinstance(x, pd.Timestamp) else x) == value_mapping[val1].date()).mean()
            else:
                ratio_1 = (df[col1] == val1).mean()
                ratio_2 = (df[col2] == value_mapping[val1]).mean()
            if ratio_1 != ratio_2:
                return False

        return True

    def compare_all_features(df):
        ratios = {column: get_value_counts_ratio(df[column]) for column in df.columns if not pd.api.types.is_datetime64_any_dtype(df[column])}
        similar_columns_dict = {column: [] for column in df.columns if not pd.api.types.is_datetime64_any_dtype(df[column])}

        # 고유값 비율이 같은 열들 찾기
        columns = list(ratios.keys())
        for i in range(len(columns)):
            for j in range(i + 1, len(columns)):
                if np.array_equal(ratios[columns[i]], ratios[columns[j]]):
                    similar_columns_dict[columns[i]].append(columns[j])

        # 고유값 비율이 같고 매핑도 동일한 피쳐들 찾기
        comparisons = []
        for key, values in similar_columns_dict.items():
            for value in values:
                if check_value_mapping(df, key, value):
                    comparisons.append((key, value))

        if comparisons:
            print("다음 피쳐 쌍은 고유값 비율과 양상이 동일합니다:")
            for base, compare in comparisons:
                print(f"'{base}'와(과) '{compare}'")
        else:
            print("모든 피쳐의 고유값 비율과 양상이 동일하지 않습니다.")

        return comparisons

    comparisons = compare_all_features(df)
    columns_to_remove = set()
    for _, col_to_remove in comparisons:
        columns_to_remove.add(col_to_remove)

    df = df.drop(columns=columns_to_remove)
    global df_columns
    df_columns = df.columns
    return df

# 파트 5: 통계 계산 및 추가 전처리
def finalize_preprocessing(df):
    # 날짜 기준 정렬
    df_preprocessed = df.sort_values(by=["Collect Date - Dam"])

    # 장비별 Collect Result 컬럼들 식별
    collect_result_columns_dam = [col for col in df_preprocessed.columns if 'Collect Result' in col and 'Dam' in col]
    collect_result_columns_autoclave = [col for col in df_preprocessed.columns if 'Collect Result' in col and 'AutoClave' in col]
    collect_result_columns_fill1 = [col for col in df_preprocessed.columns if 'Collect Result' in col and 'Fill1' in col]
    collect_result_columns_fill2 = [col for col in df_preprocessed.columns if 'Collect Result' in col and 'Fill2' in col]

    # Dam 장비의 평균, 표준편차, 합계 계산
    df_preprocessed['Collect_Result_Mean_Dam'] = df_preprocessed[collect_result_columns_dam].astype(float).mean(axis=1)
    df_preprocessed['Collect_Result_Std_Dam'] = df_preprocessed[collect_result_columns_dam].astype(float).std(axis=1)
    df_preprocessed['Collect_Result_Sum_Dam'] = df_preprocessed[collect_result_columns_dam].astype(float).sum(axis=1)

    # AutoClave 장비의 평균, 표준편차, 합계 계산
    df_preprocessed['Collect_Result_Mean_AutoClave'] = df_preprocessed[collect_result_columns_autoclave].astype(float).mean(axis=1)
    df_preprocessed['Collect_Result_Std_AutoClave'] = df_preprocessed[collect_result_columns_autoclave].astype(float).std(axis=1)
    df_preprocessed['Collect_Result_Sum_AutoClave'] = df_preprocessed[collect_result_columns_autoclave].astype(float).sum(axis=1)

    # Fill1 장비의 평균, 표준편차, 합계 계산
    df_preprocessed['Collect_Result_Mean_Fill1'] = df_preprocessed[collect_result_columns_fill1].astype(float).mean(axis=1)
    df_preprocessed['Collect_Result_Std_Fill1'] = df_preprocessed[collect_result_columns_fill1].astype(float).std(axis=1)
    df_preprocessed['Collect_Result_Sum_Fill1'] = df_preprocessed[collect_result_columns_fill1].astype(float).sum(axis=1)

    # Fill2 장비의 평균, 표준편차, 합계 계산
    df_preprocessed['Collect_Result_Mean_Fill2'] = df_preprocessed[collect_result_columns_fill2].astype(float).mean(axis=1)
    df_preprocessed['Collect_Result_Std_Fill2'] = df_preprocessed[collect_result_columns_fill2].astype(float).std(axis=1)
    df_preprocessed['Collect_Result_Sum_Fill2'] = df_preprocessed[collect_result_columns_fill2].astype(float).sum(axis=1)

    # 각 장비 간의 시간 차이 계산 (초 단위)
    df_preprocessed['Time_Difference_Dam_Fill1'] = (df_preprocessed['Collect Date - Dam'] - df_preprocessed['Collect Date - Fill1']).dt.total_seconds()
    df_preprocessed['Time_Difference_Dam_Fill2'] = (df_preprocessed['Collect Date - Dam'] - df_preprocessed['Collect Date - Fill2']).dt.total_seconds()
    df_preprocessed['Time_Difference_Dam_AutoClave'] = (df_preprocessed['Collect Date - Dam'] - df_preprocessed['Collect Date - AutoClave']).dt.total_seconds()
    df_preprocessed['Time_Difference_Fill1_Fill2'] = (df_preprocessed['Collect Date - Fill1'] - df_preprocessed['Collect Date - Fill2']).dt.total_seconds()
    df_preprocessed['Time_Difference_Fill1_AutoClave'] = (df_preprocessed['Collect Date - Fill1'] - df_preprocessed['Collect Date - AutoClave']).dt.total_seconds()
    df_preprocessed['Time_Difference_Fill2_AutoClave'] = (df_preprocessed['Collect Date - Fill2'] - df_preprocessed['Collect Date - AutoClave']).dt.total_seconds()

    # 날짜 컬럼을 타임스탬프로 변환
    df_preprocessed['Collect Date - Dam'] = pd.to_datetime(df_preprocessed['Collect Date - Dam']).apply(lambda x: x.timestamp())
    df_preprocessed['Collect Date - Fill1'] = pd.to_datetime(df_preprocessed['Collect Date - Fill1']).apply(lambda x: x.timestamp())
    df_preprocessed['Collect Date - Fill2'] = pd.to_datetime(df_preprocessed['Collect Date - Fill2']).apply(lambda x: x.timestamp())
    df_preprocessed['Collect Date - AutoClave'] = pd.to_datetime(df_preprocessed['Collect Date - AutoClave']).apply(lambda x: x.timestamp())

    return df_preprocessed

# 전체 전처리 함수
def preprocess_train_dataframe(df):
    df = preprocess_initial(df)
    # df = replace_ok_with_mode(df)
    df = convert_to_datetime(df)
    df = reduce_dataframe(df)
    df = finalize_preprocessing(df)
    return df

# 전체 전처리 함수
def preprocess_test_dataframe(df):
    df = preprocess_initial(df)
    # df = replace_ok_with_mode(df)
    df = convert_to_datetime(df)
    df = finalize_preprocessing(df)
    return df

# %%
# 데이터프레임을 전처리 함수에 넣어서 실행
df_preprocessed = preprocess_train_dataframe(df_concat)
# Out:
# 다음 피쳐 쌍은 고유값 비율과 양상이 동일합니다:
# 'Equipment - Dam'와(과) 'Collect Result - Dam'
# 'Equipment - Dam'와(과) 'Collect Result.1 - Dam'
# 'Equipment - Dam'와(과) 'Collect Result.2 - Dam'
# 'Equipment - Dam'와(과) 'Collect Result.7 - Dam'
# 'Equipment - Dam'와(과) 'Collect Result.9 - Dam'
# 'Model.Suffix - Dam'와(과) 'Model.Suffix - AutoClave'
# 'Model.Suffix - Dam'와(과) 'Model.Suffix - Fill1'
# 'Model.Suffix - Dam'와(과) 'Model.Suffix - Fill2'
# 'Workorder - Dam'와(과) 'Workorder - AutoClave'
# 'Workorder - Dam'와(과) 'Workorder - Fill1'
# 'Workorder - Dam'와(과) 'Workorder - Fill2'
# 'Collect Result - Dam'와(과) 'Collect Result.1 - Dam'
# 'Collect Result - Dam'와(과) 'Collect Result.2 - Dam'
# 'Collect Result - Dam'와(과) 'Collect Result.7 - Dam'
# 'Collect Result - Dam'와(과) 'Collect Result.9 - Dam'
# 'Collect Result.1 - Dam'와(과) 'Collect Result.2 - Dam'
# 'Collect Result.1 - Dam'와(과) 'Collect Result.7 - Dam'
# 'Collect Result.1 - Dam'와(과) 'Collect Result.9 - Dam'
# 'Collect Result.2 - Dam'와(과) 'Collect Result.7 - Dam'
# 'Collect Result.2 - Dam'와(과) 'Collect Result.9 - Dam'
# 'Collect Result.7 - Dam'와(과) 'Collect Result.9 - Dam'
# 'Collect Result.24 - Dam'와(과) 'Collect Result.25 - Dam'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.28 - Dam'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.29 - Dam'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.30 - Dam'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.33 - Dam'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.35 - Dam'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.17 - Fill1'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.18 - Fill1'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.19 - Fill1'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.20 - Fill1'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.21 - Fill1'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.22 - Fill1'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.23 - Fill1'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.27 - Fill2'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.28 - Fill2'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.29 - Fill2'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.27 - Dam'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.29 - Dam'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.30 - Dam'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.33 - Dam'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.35 - Dam'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.17 - Fill1'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.18 - Fill1'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.19 - Fill1'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.20 - Fill1'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.21 - Fill1'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.22 - Fill1'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.23 - Fill1'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.27 - Fill2'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.28 - Fill2'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.29 - Fill2'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.28 - Dam'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.30 - Dam'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.33 - Dam'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.35 - Dam'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.17 - Fill1'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.18 - Fill1'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.19 - Fill1'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.20 - Fill1'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.21 - Fill1'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.22 - Fill1'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.23 - Fill1'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.27 - Fill2'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.28 - Fill2'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.29 - Fill2'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.29 - Dam'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.33 - Dam'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.35 - Dam'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.17 - Fill1'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.18 - Fill1'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.19 - Fill1'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.20 - Fill1'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.21 - Fill1'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.22 - Fill1'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.23 - Fill1'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.27 - Fill2'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.28 - Fill2'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.29 - Fill2'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.30 - Dam'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.35 - Dam'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.17 - Fill1'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.18 - Fill1'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.19 - Fill1'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.20 - Fill1'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.21 - Fill1'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.22 - Fill1'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.23 - Fill1'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.27 - Fill2'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.28 - Fill2'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.29 - Fill2'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.33 - Dam'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.35 - Dam'와(과) 'Collect Result.17 - Fill1'
# 'Collect Result.35 - Dam'와(과) 'Collect Result.18 - Fill1'
# 'Collect Result.35 - Dam'와(과) 'Collect Result.19 - Fill1'
# 'Collect Result.35 - Dam'와(과) 'Collect Result.20 - Fill1'
# 'Collect Result.35 - Dam'와(과) 'Collect Result.21 - Fill1'
# 'Collect Result.35 - Dam'와(과) 'Collect Result.22 - Fill1'
# 'Collect Result.35 - Dam'와(과) 'Collect Result.23 - Fill1'
# 'Collect Result.35 - Dam'와(과) 'Collect Result.27 - Fill2'
# 'Collect Result.35 - Dam'와(과) 'Collect Result.28 - Fill2'
# 'Collect Result.35 - Dam'와(과) 'Collect Result.29 - Fill2'
# 'Collect Result.35 - Dam'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.35 - Dam'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.35 - Dam'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.35 - Dam'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.35 - Dam'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.43 - Dam'와(과) 'Collect Result.44 - Dam'
# 'Collect Result.43 - Dam'와(과) 'Collect Result.45 - Dam'
# 'Collect Result.44 - Dam'와(과) 'Collect Result.45 - Dam'
# 'Collect Result.46 - Dam'와(과) 'Collect Result.48 - Dam'
# 'Collect Result.51 - Dam'와(과) 'Collect Result.52 - Dam'
# 'Collect Result.51 - Dam'와(과) 'Collect Result.53 - Dam'
# 'Collect Result.51 - Dam'와(과) 'Collect Result.54 - Dam'
# 'Collect Result.52 - Dam'와(과) 'Collect Result.53 - Dam'
# 'Collect Result.52 - Dam'와(과) 'Collect Result.54 - Dam'
# 'Collect Result.53 - Dam'와(과) 'Collect Result.54 - Dam'
# 'Collect Result.59 - Dam'와(과) 'Collect Result.60 - Dam'
# 'Collect Result.59 - Dam'와(과) 'Collect Result.61 - Dam'
# 'Collect Result.60 - Dam'와(과) 'Collect Result.61 - Dam'
# 'Collect Result.62 - Dam'와(과) 'Collect Result.64 - Dam'
# 'Model.Suffix - AutoClave'와(과) 'Model.Suffix - Fill1'
# 'Model.Suffix - AutoClave'와(과) 'Model.Suffix - Fill2'
# 'Workorder - AutoClave'와(과) 'Workorder - Fill1'
# 'Workorder - AutoClave'와(과) 'Workorder - Fill2'
# 'Model.Suffix - Fill1'와(과) 'Model.Suffix - Fill2'
# 'Workorder - Fill1'와(과) 'Workorder - Fill2'
# 'Collect Result.1 - Fill1'와(과) 'Collect Result.4 - Fill1'
# 'Collect Result.3 - Fill1'와(과) 'Collect Result.6 - Fill1'
# 'Collect Result.17 - Fill1'와(과) 'Collect Result.18 - Fill1'
# 'Collect Result.17 - Fill1'와(과) 'Collect Result.19 - Fill1'
# 'Collect Result.17 - Fill1'와(과) 'Collect Result.20 - Fill1'
# 'Collect Result.17 - Fill1'와(과) 'Collect Result.21 - Fill1'
# 'Collect Result.17 - Fill1'와(과) 'Collect Result.22 - Fill1'
# 'Collect Result.17 - Fill1'와(과) 'Collect Result.23 - Fill1'
# 'Collect Result.17 - Fill1'와(과) 'Collect Result.27 - Fill2'
# 'Collect Result.17 - Fill1'와(과) 'Collect Result.28 - Fill2'
# 'Collect Result.17 - Fill1'와(과) 'Collect Result.29 - Fill2'
# 'Collect Result.17 - Fill1'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.17 - Fill1'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.17 - Fill1'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.17 - Fill1'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.17 - Fill1'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.18 - Fill1'와(과) 'Collect Result.19 - Fill1'
# 'Collect Result.18 - Fill1'와(과) 'Collect Result.20 - Fill1'
# 'Collect Result.18 - Fill1'와(과) 'Collect Result.21 - Fill1'
# 'Collect Result.18 - Fill1'와(과) 'Collect Result.22 - Fill1'
# 'Collect Result.18 - Fill1'와(과) 'Collect Result.23 - Fill1'
# 'Collect Result.18 - Fill1'와(과) 'Collect Result.27 - Fill2'
# 'Collect Result.18 - Fill1'와(과) 'Collect Result.28 - Fill2'
# 'Collect Result.18 - Fill1'와(과) 'Collect Result.29 - Fill2'
# 'Collect Result.18 - Fill1'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.18 - Fill1'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.18 - Fill1'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.18 - Fill1'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.18 - Fill1'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.19 - Fill1'와(과) 'Collect Result.20 - Fill1'
# 'Collect Result.19 - Fill1'와(과) 'Collect Result.21 - Fill1'
# 'Collect Result.19 - Fill1'와(과) 'Collect Result.22 - Fill1'
# 'Collect Result.19 - Fill1'와(과) 'Collect Result.23 - Fill1'
# 'Collect Result.19 - Fill1'와(과) 'Collect Result.27 - Fill2'
# 'Collect Result.19 - Fill1'와(과) 'Collect Result.28 - Fill2'
# 'Collect Result.19 - Fill1'와(과) 'Collect Result.29 - Fill2'
# 'Collect Result.19 - Fill1'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.19 - Fill1'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.19 - Fill1'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.19 - Fill1'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.19 - Fill1'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.20 - Fill1'와(과) 'Collect Result.21 - Fill1'
# 'Collect Result.20 - Fill1'와(과) 'Collect Result.22 - Fill1'
# 'Collect Result.20 - Fill1'와(과) 'Collect Result.23 - Fill1'
# 'Collect Result.20 - Fill1'와(과) 'Collect Result.27 - Fill2'
# 'Collect Result.20 - Fill1'와(과) 'Collect Result.28 - Fill2'
# 'Collect Result.20 - Fill1'와(과) 'Collect Result.29 - Fill2'
# 'Collect Result.20 - Fill1'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.20 - Fill1'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.20 - Fill1'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.20 - Fill1'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.20 - Fill1'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.21 - Fill1'와(과) 'Collect Result.22 - Fill1'
# 'Collect Result.21 - Fill1'와(과) 'Collect Result.23 - Fill1'
# 'Collect Result.21 - Fill1'와(과) 'Collect Result.27 - Fill2'
# 'Collect Result.21 - Fill1'와(과) 'Collect Result.28 - Fill2'
# 'Collect Result.21 - Fill1'와(과) 'Collect Result.29 - Fill2'
# 'Collect Result.21 - Fill1'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.21 - Fill1'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.21 - Fill1'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.21 - Fill1'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.21 - Fill1'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.22 - Fill1'와(과) 'Collect Result.23 - Fill1'
# 'Collect Result.22 - Fill1'와(과) 'Collect Result.27 - Fill2'
# 'Collect Result.22 - Fill1'와(과) 'Collect Result.28 - Fill2'
# 'Collect Result.22 - Fill1'와(과) 'Collect Result.29 - Fill2'
# 'Collect Result.22 - Fill1'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.22 - Fill1'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.22 - Fill1'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.22 - Fill1'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.22 - Fill1'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.23 - Fill1'와(과) 'Collect Result.27 - Fill2'
# 'Collect Result.23 - Fill1'와(과) 'Collect Result.28 - Fill2'
# 'Collect Result.23 - Fill1'와(과) 'Collect Result.29 - Fill2'
# 'Collect Result.23 - Fill1'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.23 - Fill1'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.23 - Fill1'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.23 - Fill1'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.23 - Fill1'와(과) 'Collect Result.34 - Fill2'
# 'Equipment - Fill2'와(과) 'Collect Result.24 - Fill2'
# 'Equipment - Fill2'와(과) 'Collect Result.25 - Fill2'
# 'Collect Result - Fill2'와(과) 'Collect Result.7 - Fill2'
# 'Collect Result.5 - Fill2'와(과) 'Collect Result.8 - Fill2'
# 'Collect Result.18 - Fill2'와(과) 'Collect Result.20 - Fill2'
# 'Collect Result.19 - Fill2'와(과) 'Collect Result.23 - Fill2'
# 'Collect Result.21 - Fill2'와(과) 'Collect Result.22 - Fill2'
# 'Collect Result.24 - Fill2'와(과) 'Collect Result.25 - Fill2'
# 'Collect Result.27 - Fill2'와(과) 'Collect Result.28 - Fill2'
# 'Collect Result.27 - Fill2'와(과) 'Collect Result.29 - Fill2'
# 'Collect Result.27 - Fill2'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.27 - Fill2'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.27 - Fill2'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.27 - Fill2'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.27 - Fill2'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.28 - Fill2'와(과) 'Collect Result.29 - Fill2'
# 'Collect Result.28 - Fill2'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.28 - Fill2'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.28 - Fill2'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.28 - Fill2'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.28 - Fill2'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.29 - Fill2'와(과) 'Collect Result.30 - Fill2'
# 'Collect Result.29 - Fill2'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.29 - Fill2'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.29 - Fill2'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.29 - Fill2'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.30 - Fill2'와(과) 'Collect Result.31 - Fill2'
# 'Collect Result.30 - Fill2'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.30 - Fill2'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.30 - Fill2'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.31 - Fill2'와(과) 'Collect Result.32 - Fill2'
# 'Collect Result.31 - Fill2'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.31 - Fill2'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.32 - Fill2'와(과) 'Collect Result.33 - Fill2'
# 'Collect Result.32 - Fill2'와(과) 'Collect Result.34 - Fill2'
# 'Collect Result.33 - Fill2'와(과) 'Collect Result.34 - Fill2'

# %%
df_train = df_preprocessed.copy()

# %%
df_train.shape
# Out:
# (4700, 115)

# %%
y_train = df_train.target
df_train.drop(columns = ['target'],inplace =True)

# %% [markdown]
# ### SHAP

# %%
# # NaN 및 무한대 값 처리
# df_train_shap = df_train.replace([np.inf, -np.inf], np.nan).dropna()
# # df_encoded = df_encoded.applymap(lambda x: x if x > 1e-2 else 0)
# df_train_shap['target'] = df_train_shap['target'].map({'AbNormal': 1, 'Normal': 0})
# df_cleaned = df_train_shap.drop(columns=['Workorder - Dam'])

# # 문자열 데이터를 범주형으로 변환
# categorical_cols = df_cleaned.select_dtypes(include=['object']).columns
# df_cleaned[categorical_cols] = df_cleaned[categorical_cols].astype('category')

# # 범주형 데이터를 원-핫 인코딩
# df_encoded = pd.get_dummies(df_cleaned, drop_first=True)

# # 독립 변수와 종속 변수 분리
# X_shap = df_encoded.drop(columns=['target'])
# y_shap = df_encoded['target']

# # 학습 데이터와 테스트 데이터 분리
# X_train, X_test, y_train, y_test = train_test_split(X_shap, y_shap, test_size=0.3, random_state=42)

# %%
# # XGBoost 모델 학습
# model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')
# model.fit(X_train, y_train)

# # 예측
# y_pred = model.predict(X_test)

# # F1 score 계산
# f1 = f1_score(y_test, y_pred)
# print(f'F1 Score: {f1}')

# %%
# # SHAP 값 계산
# explainer = shap.TreeExplainer(model)
# shap_values = explainer.shap_values(X_test)

# # SHAP 값을 데이터프레임으로 변환
# shap_values_df = pd.DataFrame(shap_values, columns=X_test.columns)

# # 각 피쳐의 평균 절대 SHAP 값 계산
# mean_abs_shap_values = shap_values_df.abs().mean()

# # 상위 N개의 피쳐 선택 (여기서는 상위 10개 피쳐를 예시로 선택)
# top_features = mean_abs_shap_values.sort_values(ascending=False).head(50)
# # 평균 절대 SHAP 값이 0.01 이상인 피처 선택
# selected_features = top_features[top_features >= 0.01]

# # 피처 이름만 추출
# selected_feature_names = selected_features.index.tolist()

# # 결과 출력
# print("평균 절대 SHAP 값이 0.01 이상인 피처들:\n", selected_feature_names)

# %%
# # SHAP 값 계산
# explainer = shap.TreeExplainer(model)
# shap_values = explainer.shap_values(X_test)

# # SHAP 값 시각화
# shap.summary_plot(shap_values, X_test, plot_type="bar")
# shap.summary_plot(shap_values, X_test)

# %%
# X_train_shap = X_shap[selected_feature_names]

# %% [markdown]
# ## 3. 모델 학습

# %% [markdown]
# ### 모델 정의

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import make_scorer, f1_score
from sklearn.model_selection import cross_val_score
import optuna
import warnings
warnings.filterwarnings("ignore")

model = RandomForestClassifier(random_state=RANDOM_STATE)

# %% [markdown]
# ### 모델 학습

# %%
features = []

for col in df_train.columns:
    try:
        df_train[col] = df_train[col].astype(int)
        features.append(col)
    except:
        continue

if "Set ID" in features:
    features.remove("Set ID")

train_x = df_train[features]
train_y = y_train

# %%
train_x.shape
# Out:
# (4700, 108)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(train_y)

# %% [markdown]
# ### Catboost

# %%
# 하이퍼파라미터 튜닝을 위한 목적 함수 정의 + L2 추가 
def objective_decision(trial):
    cat_depth = trial.suggest_int('depth', 2, 10, step=1)
    cat_learning_rate = trial.suggest_float('learning_rate', 0.001, 0.01, step=0.001)
    cat_iterations = trial.suggest_int('iterations', 100, 300, step=10)
    cat_l2_leaf_reg = trial.suggest_float('l2_leaf_reg', 1e-5, 1e-1, log=True)

    classifier_obj = CatBoostClassifier(
        depth=cat_depth,
        learning_rate=cat_learning_rate,
        iterations=cat_iterations,
        l2_leaf_reg=cat_l2_leaf_reg,
        early_stopping_rounds=50,  # 조기 종료 설정
        verbose=0  # 훈련 중 출력 억제
    )

    # 교차 검증을 통해 F1 스코어 계산
    score = cross_val_score(classifier_obj, train_x, y_encoded, cv=5, n_jobs=-1, scoring='f1', error_score='raise')
    mean_f1 = score.mean()
    return mean_f1

# 최적화 실행
study = optuna.create_study(sampler=optuna.samplers.TPESampler(seed=100), direction="maximize")
study.optimize(objective_decision, n_trials=1) 

# 최적화 결과 보기
print("Best score:", study.best_value)
print("Best parameters:", study.best_params)
# Out:
# [I 2024-08-06 14:09:22,861] A new study created in memory with name: no-name-8787059c-78fe-4838-a235-665ad02c3594
# [I 2024-08-06 14:09:25,721] Trial 0 finished with value: 0.3307299486385614 and parameters: {'depth': 6, 'learning_rate': 0.003, 'iterations': 180, 'l2_leaf_reg': 0.023938918670661075}. Best is trial 0 with value: 0.3307299486385614.
# Best score: 0.3307299486385614
# Best parameters: {'depth': 6, 'learning_rate': 0.003, 'iterations': 180, 'l2_leaf_reg': 0.023938918670661075}

# %%
cat = CatBoostClassifier(**study.best_params)
cat.fit(train_x, y_encoded)
# Out:
# 0:	learn: 0.6926806	total: 4.02ms	remaining: 719ms
# 1:	learn: 0.6922795	total: 7.98ms	remaining: 710ms
# 2:	learn: 0.6917140	total: 12.1ms	remaining: 712ms
# 3:	learn: 0.6913282	total: 16.2ms	remaining: 713ms
# 4:	learn: 0.6909240	total: 19.7ms	remaining: 690ms
# 5:	learn: 0.6904873	total: 23ms	remaining: 667ms
# 6:	learn: 0.6901185	total: 26.5ms	remaining: 655ms
# 7:	learn: 0.6897283	total: 29.7ms	remaining: 639ms
# 8:	learn: 0.6893401	total: 33.2ms	remaining: 631ms
# 9:	learn: 0.6889333	total: 36.3ms	remaining: 617ms
# 10:	learn: 0.6885180	total: 39.7ms	remaining: 610ms
# 11:	learn: 0.6881081	total: 43.3ms	remaining: 606ms
# 12:	learn: 0.6875195	total: 46.5ms	remaining: 597ms
# 13:	learn: 0.6872291	total: 50.6ms	remaining: 600ms
# 14:	learn: 0.6868576	total: 53.9ms	remaining: 593ms
# 15:	learn: 0.6864054	total: 57.4ms	remaining: 589ms
# 16:	learn: 0.6858945	total: 60.7ms	remaining: 582ms
# 17:	learn: 0.6853529	total: 64.2ms	remaining: 578ms
# 18:	learn: 0.6847228	total: 67.6ms	remaining: 573ms
# 19:	learn: 0.6843492	total: 70.6ms	remaining: 565ms
# 20:	learn: 0.6838852	total: 74.2ms	remaining: 562ms
# 21:	learn: 0.6833421	total: 77.6ms	remaining: 557ms
# 22:	learn: 0.6829656	total: 81.4ms	remaining: 556ms
# 23:	learn: 0.6824553	total: 84.7ms	remaining: 550ms
# 24:	learn: 0.6821051	total: 88.1ms	remaining: 546ms
# 25:	learn: 0.6817019	total: 92ms	remaining: 545ms
# 26:	learn: 0.6811743	total: 95.1ms	remaining: 539ms
# 27:	learn: 0.6806718	total: 98.6ms	remaining: 535ms
# 28:	learn: 0.6803963	total: 102ms	remaining: 531ms
# 29:	learn: 0.6800945	total: 105ms	remaining: 525ms
# 30:	learn: 0.6797668	total: 109ms	remaining: 523ms
# 31:	learn: 0.6794575	total: 112ms	remaining: 518ms
# 32:	learn: 0.6789460	total: 116ms	remaining: 519ms
# 33:	learn: 0.6785631	total: 120ms	remaining: 515ms
# 34:	learn: 0.6782497	total: 124ms	remaining: 514ms
# 35:	learn: 0.6779132	total: 127ms	remaining: 510ms
# 36:	learn: 0.6774377	total: 131ms	remaining: 505ms
# 37:	learn: 0.6770331	total: 134ms	remaining: 501ms
# 38:	learn: 0.6766955	total: 138ms	remaining: 498ms
# 39:	learn: 0.6763043	total: 141ms	remaining: 494ms
# 40:	learn: 0.6759422	total: 145ms	remaining: 490ms
# 41:	learn: 0.6756917	total: 148ms	remaining: 487ms
# 42:	learn: 0.6752747	total: 152ms	remaining: 483ms
# 43:	learn: 0.6749077	total: 155ms	remaining: 480ms
# 44:	learn: 0.6745291	total: 159ms	remaining: 477ms
# 45:	learn: 0.6742794	total: 163ms	remaining: 474ms
# 46:	learn: 0.6738138	total: 167ms	remaining: 472ms
# 47:	learn: 0.6735271	total: 170ms	remaining: 468ms
# 48:	learn: 0.6731722	total: 174ms	remaining: 466ms
# 49:	learn: 0.6729285	total: 178ms	remaining: 462ms
# 50:	learn: 0.6726483	total: 181ms	remaining: 458ms
# 51:	learn: 0.6722773	total: 184ms	remaining: 454ms
# 52:	learn: 0.6719933	total: 189ms	remaining: 452ms
# 53:	learn: 0.6716430	total: 192ms	remaining: 448ms
# 54:	learn: 0.6714174	total: 196ms	remaining: 445ms
# 55:	learn: 0.6710969	total: 200ms	remaining: 442ms
# 56:	learn: 0.6707835	total: 203ms	remaining: 438ms
# 57:	learn: 0.6705075	total: 207ms	remaining: 435ms
# 58:	learn: 0.6700574	total: 210ms	remaining: 431ms
# 59:	learn: 0.6697050	total: 214ms	remaining: 428ms
# 60:	learn: 0.6694631	total: 218ms	remaining: 424ms
# 61:	learn: 0.6690381	total: 222ms	remaining: 423ms
# 62:	learn: 0.6687570	total: 226ms	remaining: 419ms
# 63:	learn: 0.6685386	total: 229ms	remaining: 416ms
# 64:	learn: 0.6682818	total: 233ms	remaining: 412ms
# 65:	learn: 0.6680475	total: 236ms	remaining: 408ms
# 66:	learn: 0.6677900	total: 240ms	remaining: 404ms
# 67:	learn: 0.6675606	total: 243ms	remaining: 400ms
# 68:	learn: 0.6673205	total: 246ms	remaining: 396ms
# 69:	learn: 0.6671286	total: 250ms	remaining: 392ms
# 70:	learn: 0.6668168	total: 253ms	remaining: 389ms
# 71:	learn: 0.6664252	total: 257ms	remaining: 386ms
# 72:	learn: 0.6662529	total: 262ms	remaining: 383ms
# 73:	learn: 0.6660238	total: 265ms	remaining: 380ms
# 74:	learn: 0.6657748	total: 269ms	remaining: 376ms
# 75:	learn: 0.6656147	total: 271ms	remaining: 371ms
# 76:	learn: 0.6654125	total: 275ms	remaining: 367ms
# 77:	learn: 0.6652097	total: 278ms	remaining: 364ms
# 78:	learn: 0.6649788	total: 282ms	remaining: 360ms
# 79:	learn: 0.6648146	total: 284ms	remaining: 355ms
# 80:	learn: 0.6645898	total: 288ms	remaining: 352ms
# 81:	learn: 0.6643509	total: 291ms	remaining: 348ms
# 82:	learn: 0.6641889	total: 294ms	remaining: 344ms
# 83:	learn: 0.6639631	total: 298ms	remaining: 341ms
# 84:	learn: 0.6637337	total: 302ms	remaining: 338ms
# 85:	learn: 0.6634139	total: 305ms	remaining: 334ms
# 86:	learn: 0.6632363	total: 308ms	remaining: 330ms
# 87:	learn: 0.6628509	total: 312ms	remaining: 326ms
# 88:	learn: 0.6625972	total: 315ms	remaining: 322ms
# 89:	learn: 0.6624066	total: 318ms	remaining: 318ms
# 90:	learn: 0.6621624	total: 322ms	remaining: 315ms
# 91:	learn: 0.6619466	total: 325ms	remaining: 310ms
# 92:	learn: 0.6616221	total: 328ms	remaining: 307ms
# 93:	learn: 0.6614506	total: 331ms	remaining: 303ms
# 94:	learn: 0.6611809	total: 334ms	remaining: 299ms
# 95:	learn: 0.6608939	total: 337ms	remaining: 295ms
# 96:	learn: 0.6607170	total: 340ms	remaining: 291ms
# 97:	learn: 0.6605518	total: 344ms	remaining: 288ms
# 98:	learn: 0.6603331	total: 347ms	remaining: 284ms
# 99:	learn: 0.6601657	total: 350ms	remaining: 280ms
# 100:	learn: 0.6598308	total: 353ms	remaining: 276ms
# 101:	learn: 0.6596069	total: 356ms	remaining: 273ms
# 102:	learn: 0.6594441	total: 360ms	remaining: 269ms
# 103:	learn: 0.6592879	total: 363ms	remaining: 265ms
# 104:	learn: 0.6590180	total: 366ms	remaining: 261ms
# 105:	learn: 0.6588620	total: 369ms	remaining: 258ms
# 106:	learn: 0.6585759	total: 373ms	remaining: 254ms
# 107:	learn: 0.6583817	total: 376ms	remaining: 250ms
# 108:	learn: 0.6581633	total: 379ms	remaining: 247ms
# 109:	learn: 0.6579048	total: 382ms	remaining: 243ms
# 110:	learn: 0.6576462	total: 385ms	remaining: 240ms
# 111:	learn: 0.6574993	total: 389ms	remaining: 236ms
# 112:	learn: 0.6571832	total: 391ms	remaining: 232ms
# 113:	learn: 0.6570663	total: 395ms	remaining: 229ms
# 114:	learn: 0.6569383	total: 398ms	remaining: 225ms
# 115:	learn: 0.6568295	total: 401ms	remaining: 221ms
# 116:	learn: 0.6566772	total: 404ms	remaining: 218ms
# 117:	learn: 0.6564443	total: 407ms	remaining: 214ms
# 118:	learn: 0.6563360	total: 410ms	remaining: 210ms
# 119:	learn: 0.6561911	total: 414ms	remaining: 207ms
# 120:	learn: 0.6560175	total: 416ms	remaining: 203ms
# 121:	learn: 0.6558564	total: 420ms	remaining: 200ms
# 122:	learn: 0.6556555	total: 423ms	remaining: 196ms
# 123:	learn: 0.6555404	total: 426ms	remaining: 192ms
# 124:	learn: 0.6552693	total: 430ms	remaining: 189ms
# 125:	learn: 0.6551100	total: 432ms	remaining: 185ms
# 126:	learn: 0.6549700	total: 436ms	remaining: 182ms
# 127:	learn: 0.6547714	total: 440ms	remaining: 179ms
# 128:	learn: 0.6545423	total: 443ms	remaining: 175ms
# 129:	learn: 0.6544140	total: 446ms	remaining: 171ms
# 130:	learn: 0.6542968	total: 449ms	remaining: 168ms
# 131:	learn: 0.6542023	total: 453ms	remaining: 165ms
# 132:	learn: 0.6540633	total: 456ms	remaining: 161ms
# 133:	learn: 0.6539398	total: 458ms	remaining: 157ms
# 134:	learn: 0.6538388	total: 462ms	remaining: 154ms
# 135:	learn: 0.6536493	total: 465ms	remaining: 150ms
# 136:	learn: 0.6535166	total: 468ms	remaining: 147ms
# 137:	learn: 0.6533617	total: 471ms	remaining: 143ms
# 138:	learn: 0.6531140	total: 474ms	remaining: 140ms
# 139:	learn: 0.6529211	total: 479ms	remaining: 137ms
# 140:	learn: 0.6527931	total: 482ms	remaining: 133ms
# 141:	learn: 0.6526732	total: 485ms	remaining: 130ms
# 142:	learn: 0.6525228	total: 488ms	remaining: 126ms
# 143:	learn: 0.6523329	total: 492ms	remaining: 123ms
# 144:	learn: 0.6521580	total: 495ms	remaining: 120ms
# 145:	learn: 0.6519961	total: 498ms	remaining: 116ms
# 146:	learn: 0.6519221	total: 501ms	remaining: 112ms
# 147:	learn: 0.6517993	total: 504ms	remaining: 109ms
# 148:	learn: 0.6516961	total: 516ms	remaining: 107ms
# 149:	learn: 0.6515045	total: 519ms	remaining: 104ms
# 150:	learn: 0.6514178	total: 523ms	remaining: 100ms
# 151:	learn: 0.6512079	total: 526ms	remaining: 96.8ms
# 152:	learn: 0.6511113	total: 529ms	remaining: 93.4ms
# 153:	learn: 0.6509048	total: 532ms	remaining: 89.9ms
# 154:	learn: 0.6507119	total: 536ms	remaining: 86.4ms
# 155:	learn: 0.6506263	total: 539ms	remaining: 82.9ms
# 156:	learn: 0.6505266	total: 542ms	remaining: 79.4ms
# 157:	learn: 0.6504174	total: 546ms	remaining: 76ms
# 158:	learn: 0.6502723	total: 549ms	remaining: 72.5ms
# 159:	learn: 0.6500940	total: 552ms	remaining: 69ms
# 160:	learn: 0.6499628	total: 555ms	remaining: 65.5ms
# 161:	learn: 0.6498566	total: 558ms	remaining: 62ms
# 162:	learn: 0.6496918	total: 561ms	remaining: 58.6ms
# 163:	learn: 0.6495716	total: 565ms	remaining: 55.1ms
# 164:	learn: 0.6494255	total: 568ms	remaining: 51.6ms
# 165:	learn: 0.6492667	total: 571ms	remaining: 48.2ms
# 166:	learn: 0.6490941	total: 574ms	remaining: 44.7ms
# 167:	learn: 0.6489667	total: 578ms	remaining: 41.3ms
# 168:	learn: 0.6488901	total: 581ms	remaining: 37.8ms
# 169:	learn: 0.6487068	total: 584ms	remaining: 34.3ms
# 170:	learn: 0.6485850	total: 587ms	remaining: 30.9ms
# 171:	learn: 0.6485082	total: 590ms	remaining: 27.4ms
# 172:	learn: 0.6484022	total: 593ms	remaining: 24ms
# 173:	learn: 0.6482928	total: 597ms	remaining: 20.6ms
# 174:	learn: 0.6481081	total: 600ms	remaining: 17.1ms
# 175:	learn: 0.6480100	total: 603ms	remaining: 13.7ms
# 176:	learn: 0.6478636	total: 606ms	remaining: 10.3ms
# 177:	learn: 0.6476392	total: 609ms	remaining: 6.84ms
# 178:	learn: 0.6474854	total: 613ms	remaining: 3.42ms
# 179:	learn: 0.6473586	total: 615ms	remaining: 0us

# %% [markdown]
# ### xgboost

# %%
from xgboost import XGBClassifier

def objective_decision(trial):
    xgbm_n_estimators = trial.suggest_int('n_estimators', 300, 400, step=50)
    xgbm_learning_rate = trial.suggest_float('learning_rate', 0.02, 0.05, step=0.01)
    xgbm_max_depth = trial.suggest_int('max_depth', 3, 10, step=1)
    xgbm_gamma = trial.suggest_float('gamma', 0.0, 0.5, step=0.1)
    xgbm_min_child_weight = trial.suggest_int('min_child_weight', 1, 10, step=1)
    xgbm_subsample = trial.suggest_float('subsample', 0.5, 1.0, step=0.1)
    xgbm_colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1.0, step=0.1)

    classifier_obj = XGBClassifier(
        n_estimators=xgbm_n_estimators,
        learning_rate=xgbm_learning_rate,
        max_depth=xgbm_max_depth,
        gamma=xgbm_gamma,
        min_child_weight=xgbm_min_child_weight,
        subsample=xgbm_subsample,
        colsample_bytree=xgbm_colsample_bytree,
        use_label_encoder=False,
        eval_metric='logloss'
    )

    score = cross_val_score(classifier_obj, train_x, y_encoded, cv=5, n_jobs=-1, scoring='f1', error_score='raise')
    mean_f1 = score.mean()
    return mean_f1

# 최적화 실행
study = optuna.create_study(sampler=optuna.samplers.TPESampler(seed=100), direction="maximize")
study.optimize(objective_decision, n_trials=1) 

# 최적화 결과 보기
print("Best score:", study.best_value)
print("Best parameters:", study.best_params)
# Out:
# [I 2024-08-06 14:09:26,564] A new study created in memory with name: no-name-ee57da04-438a-45a6-b7b4-77381f667041
# [I 2024-08-06 14:09:27,885] Trial 0 finished with value: 0.33781804171484087 and parameters: {'n_estimators': 350, 'learning_rate': 0.03, 'max_depth': 6, 'gamma': 0.5, 'min_child_weight': 1, 'subsample': 0.5, 'colsample_bytree': 0.9}. Best is trial 0 with value: 0.33781804171484087.
# Best score: 0.33781804171484087
# Best parameters: {'n_estimators': 350, 'learning_rate': 0.03, 'max_depth': 6, 'gamma': 0.5, 'min_child_weight': 1, 'subsample': 0.5, 'colsample_bytree': 0.9}

# %%
xgbm = XGBClassifier(**study.best_params)
xgbm.fit(train_x, y_encoded)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.5, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.03, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=350, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# y_encoded #0은 AbNormal, 1은 Normal

# %% [markdown]
# ### RandomForest

# %%
def objective(trial):
    # 하이퍼파라미터 설정
    rf_n_estimators = trial.suggest_int('n_estimators', 200, 400, step=20)
    rf_max_depth = trial.suggest_int('max_depth', 2, 15, step=2)
    rf_min_samples_split = trial.suggest_int('min_samples_split', 5, 20, step=2)
    rf_max_leaf_nodes = trial.suggest_int('max_leaf_nodes', 2, 60, step=2)
    rf_min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10, step=1)
    rf_max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2'])

    classifier_obj = RandomForestClassifier(
        n_estimators=rf_n_estimators,
        max_depth=rf_max_depth,
        min_samples_split=rf_min_samples_split,
        max_leaf_nodes=rf_max_leaf_nodes,
        min_samples_leaf=rf_min_samples_leaf,
        max_features=rf_max_features,
        random_state=100
    )

    # 교차 검증을 통해 F1 스코어 계산
    score = cross_val_score(classifier_obj, train_x, y_encoded, cv=5, n_jobs=-1, scoring='f1')
    mean_f1 = score.mean()
    return mean_f1

# 최적화 실행
study = optuna.create_study(sampler=optuna.samplers.TPESampler(seed=100), direction="maximize")
study.optimize(objective, n_trials=2)

# 최적화 결과 보기
print("Best score:", study.best_value)
print("Best parameters:", study.best_params)
# Out:
# [I 2024-08-06 14:09:28,450] A new study created in memory with name: no-name-a8d5850e-615f-4055-a36a-d5d0d0fa57ef
# [I 2024-08-06 14:09:29,291] Trial 0 finished with value: 0.33737676868004085 and parameters: {'n_estimators': 300, 'max_depth': 4, 'min_samples_split': 11, 'max_leaf_nodes': 52, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 0 with value: 0.33737676868004085.
# [I 2024-08-06 14:09:30,361] Trial 1 finished with value: 0.3747475120276536 and parameters: {'n_estimators': 380, 'max_depth': 2, 'min_samples_split': 13, 'max_leaf_nodes': 54, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.3747475120276536.
# Best score: 0.3747475120276536
# Best parameters: {'n_estimators': 380, 'max_depth': 2, 'min_samples_split': 13, 'max_leaf_nodes': 54, 'min_samples_leaf': 3, 'max_features': 'sqrt'}

# %%
rf = RandomForestClassifier(**study.best_params)
rf.fit(train_x, y_encoded)
# Out:
# RandomForestClassifier(max_depth=2, max_leaf_nodes=54, min_samples_leaf=3,
#                        min_samples_split=13, n_estimators=380)

# %% [markdown]
# ## 4. 제출하기

# %% [markdown]
# ### 테스트 데이터 예측

# %%
df_test_y = pd.read_csv(os.path.join("submission.csv"))
df_test = pd.merge(X, df_test_y, "inner", on="Set ID")

# %%
df_test = df_test[df_columns]

# %%
df_test_preprocessed = preprocess_test_dataframe(df_test)
df_test_x = df_test_preprocessed.copy()

# %%
features = []

for col in df_test_x.columns:
    try:
        df_test_x.loc[:, col] = df_test_x[col].astype(int)
        features.append(col)
    except:
        continue

df_test_x = df_test_x[features]

# %%
train_x.shape
# Out:
# (4700, 108)

# %%
df_test_x.shape
# Out:
# (17361, 108)

# %%
cat_test_pred = cat.predict(df_test_x)
xgbm_test_pred = xgbm.predict(df_test_x)
rf_test_pred = rf.predict(df_test_x)

# %% [markdown]
# ### voting 전 평가

# %%
# 학습데이터 70%, 평가데이터 30%로 데이터 분할
X_tra, X_dev, y_tra, y_dev = train_test_split(train_x, y_encoded, test_size=0.3, stratify=train_y, random_state=0)

# %%
y_dev
# Out:
# array([1, 1, 1, ..., 0, 1, 0])

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import f1_score

averaging = VotingClassifier(
    estimators = [('xgbm', xgbm), ('cat', cat),  ('rf', rf)], voting='soft', weights=[4, 4, 3])

averaging.fit(X_tra, y_tra)

ensemble_pred = averaging.predict(X_dev)

print(f1_score(y_dev, ensemble_pred))
# Out:
# 0:	learn: 0.6926540	total: 3.36ms	remaining: 601ms
# 1:	learn: 0.6921623	total: 6.69ms	remaining: 595ms
# 2:	learn: 0.6915102	total: 9.98ms	remaining: 589ms
# 3:	learn: 0.6909843	total: 13.2ms	remaining: 582ms
# 4:	learn: 0.6904934	total: 16.3ms	remaining: 569ms
# 5:	learn: 0.6900438	total: 19.5ms	remaining: 566ms
# 6:	learn: 0.6896946	total: 22.6ms	remaining: 558ms
# 7:	learn: 0.6890610	total: 25.6ms	remaining: 550ms
# 8:	learn: 0.6886578	total: 28.9ms	remaining: 549ms
# 9:	learn: 0.6882925	total: 32ms	remaining: 545ms
# 10:	learn: 0.6878473	total: 35.4ms	remaining: 543ms
# 11:	learn: 0.6874885	total: 38.3ms	remaining: 536ms
# 12:	learn: 0.6870051	total: 41.6ms	remaining: 535ms
# 13:	learn: 0.6866883	total: 44.9ms	remaining: 532ms
# 14:	learn: 0.6864018	total: 46.8ms	remaining: 515ms
# 15:	learn: 0.6861072	total: 49.8ms	remaining: 511ms
# 16:	learn: 0.6854984	total: 53ms	remaining: 508ms
# 17:	learn: 0.6852464	total: 56.6ms	remaining: 510ms
# 18:	learn: 0.6847668	total: 59.9ms	remaining: 508ms
# 19:	learn: 0.6843348	total: 62.9ms	remaining: 503ms
# 20:	learn: 0.6838764	total: 65.9ms	remaining: 499ms
# 21:	learn: 0.6834873	total: 69.3ms	remaining: 497ms
# 22:	learn: 0.6830228	total: 72.3ms	remaining: 493ms
# 23:	learn: 0.6825703	total: 75.5ms	remaining: 491ms
# 24:	learn: 0.6822562	total: 78.5ms	remaining: 487ms
# 25:	learn: 0.6816627	total: 81.5ms	remaining: 483ms
# 26:	learn: 0.6811850	total: 84.8ms	remaining: 481ms
# 27:	learn: 0.6808081	total: 87.4ms	remaining: 474ms
# 28:	learn: 0.6805170	total: 90.2ms	remaining: 469ms
# 29:	learn: 0.6801918	total: 93.2ms	remaining: 466ms
# 30:	learn: 0.6797354	total: 95.8ms	remaining: 460ms
# 31:	learn: 0.6793232	total: 98.6ms	remaining: 456ms
# 32:	learn: 0.6788235	total: 102ms	remaining: 454ms
# 33:	learn: 0.6784212	total: 105ms	remaining: 449ms
# 34:	learn: 0.6779572	total: 108ms	remaining: 446ms
# 35:	learn: 0.6775334	total: 119ms	remaining: 476ms
# 36:	learn: 0.6772071	total: 122ms	remaining: 471ms
# 37:	learn: 0.6768385	total: 124ms	remaining: 465ms
# 38:	learn: 0.6764198	total: 127ms	remaining: 460ms
# 39:	learn: 0.6760806	total: 130ms	remaining: 454ms
# 40:	learn: 0.6756395	total: 133ms	remaining: 450ms
# 41:	learn: 0.6753647	total: 136ms	remaining: 447ms
# 42:	learn: 0.6749889	total: 139ms	remaining: 442ms
# 43:	learn: 0.6747212	total: 142ms	remaining: 438ms
# 44:	learn: 0.6744372	total: 145ms	remaining: 434ms
# 45:	learn: 0.6741219	total: 148ms	remaining: 432ms
# 46:	learn: 0.6737025	total: 152ms	remaining: 429ms
# 47:	learn: 0.6732478	total: 154ms	remaining: 425ms
# 48:	learn: 0.6729455	total: 157ms	remaining: 420ms
# 49:	learn: 0.6726262	total: 161ms	remaining: 418ms
# 50:	learn: 0.6723727	total: 164ms	remaining: 414ms
# 51:	learn: 0.6720019	total: 167ms	remaining: 410ms
# 52:	learn: 0.6718226	total: 170ms	remaining: 407ms
# 53:	learn: 0.6715384	total: 173ms	remaining: 404ms
# 54:	learn: 0.6713389	total: 176ms	remaining: 400ms
# 55:	learn: 0.6710389	total: 179ms	remaining: 396ms
# 56:	learn: 0.6706819	total: 182ms	remaining: 393ms
# 57:	learn: 0.6704608	total: 185ms	remaining: 390ms
# 58:	learn: 0.6702396	total: 187ms	remaining: 385ms
# 59:	learn: 0.6700259	total: 191ms	remaining: 382ms
# 60:	learn: 0.6698225	total: 195ms	remaining: 380ms
# 61:	learn: 0.6695984	total: 198ms	remaining: 376ms
# 62:	learn: 0.6692416	total: 202ms	remaining: 375ms
# 63:	learn: 0.6687992	total: 205ms	remaining: 371ms
# 64:	learn: 0.6685693	total: 208ms	remaining: 367ms
# 65:	learn: 0.6683079	total: 210ms	remaining: 364ms
# 66:	learn: 0.6679932	total: 213ms	remaining: 360ms
# 67:	learn: 0.6678024	total: 216ms	remaining: 356ms
# 68:	learn: 0.6675318	total: 219ms	remaining: 353ms
# 69:	learn: 0.6672667	total: 222ms	remaining: 349ms
# 70:	learn: 0.6669399	total: 225ms	remaining: 345ms
# 71:	learn: 0.6667422	total: 227ms	remaining: 341ms
# 72:	learn: 0.6663763	total: 230ms	remaining: 338ms
# 73:	learn: 0.6661641	total: 233ms	remaining: 334ms
# 74:	learn: 0.6658576	total: 236ms	remaining: 330ms
# 75:	learn: 0.6657210	total: 239ms	remaining: 327ms
# 76:	learn: 0.6653207	total: 242ms	remaining: 324ms
# 77:	learn: 0.6649787	total: 245ms	remaining: 321ms
# 78:	learn: 0.6647920	total: 248ms	remaining: 317ms
# 79:	learn: 0.6645685	total: 251ms	remaining: 314ms
# 80:	learn: 0.6643754	total: 254ms	remaining: 310ms
# 81:	learn: 0.6641274	total: 256ms	remaining: 307ms
# 82:	learn: 0.6639647	total: 259ms	remaining: 303ms
# 83:	learn: 0.6635840	total: 262ms	remaining: 300ms
# 84:	learn: 0.6633175	total: 265ms	remaining: 296ms
# 85:	learn: 0.6630064	total: 268ms	remaining: 293ms
# 86:	learn: 0.6627360	total: 271ms	remaining: 289ms
# 87:	learn: 0.6624773	total: 274ms	remaining: 286ms
# 88:	learn: 0.6621435	total: 277ms	remaining: 283ms
# 89:	learn: 0.6619730	total: 280ms	remaining: 280ms
# 90:	learn: 0.6617717	total: 283ms	remaining: 277ms
# 91:	learn: 0.6614575	total: 286ms	remaining: 274ms
# 92:	learn: 0.6612016	total: 289ms	remaining: 270ms
# 93:	learn: 0.6608777	total: 291ms	remaining: 266ms
# 94:	learn: 0.6606814	total: 294ms	remaining: 263ms
# 95:	learn: 0.6604243	total: 297ms	remaining: 260ms
# 96:	learn: 0.6602232	total: 300ms	remaining: 257ms
# 97:	learn: 0.6600323	total: 303ms	remaining: 254ms
# 98:	learn: 0.6598290	total: 307ms	remaining: 251ms
# 99:	learn: 0.6596985	total: 310ms	remaining: 248ms
# 100:	learn: 0.6594056	total: 313ms	remaining: 245ms
# 101:	learn: 0.6591819	total: 316ms	remaining: 241ms
# 102:	learn: 0.6589666	total: 319ms	remaining: 239ms
# 103:	learn: 0.6587115	total: 322ms	remaining: 235ms
# 104:	learn: 0.6583934	total: 324ms	remaining: 232ms
# 105:	learn: 0.6582371	total: 328ms	remaining: 229ms
# 106:	learn: 0.6580858	total: 330ms	remaining: 225ms
# 107:	learn: 0.6579341	total: 333ms	remaining: 222ms
# 108:	learn: 0.6577768	total: 337ms	remaining: 219ms
# 109:	learn: 0.6576205	total: 339ms	remaining: 215ms
# 110:	learn: 0.6574622	total: 341ms	remaining: 212ms

# %% [markdown]
# ### voting

# %%
from sklearn.ensemble import VotingClassifier

averaging_model = VotingClassifier(
    estimators = [('xgbm', xgbm), ('cat', cat),  ('rf', rf)], voting='soft', weights=[4, 4, 3])

averaging_model.fit(train_x, train_y)

ensemble_pred = averaging_model.predict(df_test_x)
# Out:
# 0:	learn: 0.6927189	total: 3.57ms	remaining: 640ms
# 1:	learn: 0.6923048	total: 7.07ms	remaining: 629ms
# 2:	learn: 0.6918878	total: 10.2ms	remaining: 603ms
# 3:	learn: 0.6914771	total: 13.7ms	remaining: 603ms
# 4:	learn: 0.6909559	total: 17ms	remaining: 595ms
# 5:	learn: 0.6904760	total: 20.7ms	remaining: 600ms
# 6:	learn: 0.6900814	total: 23.9ms	remaining: 591ms
# 7:	learn: 0.6895801	total: 27.2ms	remaining: 585ms
# 8:	learn: 0.6891483	total: 30.8ms	remaining: 585ms
# 9:	learn: 0.6885133	total: 34.6ms	remaining: 587ms
# 10:	learn: 0.6880854	total: 38ms	remaining: 583ms
# 11:	learn: 0.6875359	total: 41.2ms	remaining: 577ms
# 12:	learn: 0.6872281	total: 45ms	remaining: 578ms
# 13:	learn: 0.6867938	total: 48.7ms	remaining: 578ms
# 14:	learn: 0.6863737	total: 52.6ms	remaining: 578ms
# 15:	learn: 0.6859325	total: 56.1ms	remaining: 575ms
# 16:	learn: 0.6854023	total: 60.1ms	remaining: 576ms
# 17:	learn: 0.6847763	total: 63.6ms	remaining: 573ms
# 18:	learn: 0.6843894	total: 67.3ms	remaining: 570ms
# 19:	learn: 0.6840840	total: 71.3ms	remaining: 571ms
# 20:	learn: 0.6837876	total: 75ms	remaining: 568ms
# 21:	learn: 0.6834428	total: 79ms	remaining: 567ms
# 22:	learn: 0.6831095	total: 82.8ms	remaining: 565ms
# 23:	learn: 0.6825797	total: 87.3ms	remaining: 568ms
# 24:	learn: 0.6821023	total: 91.2ms	remaining: 565ms
# 25:	learn: 0.6817318	total: 94.7ms	remaining: 561ms
# 26:	learn: 0.6812330	total: 98.1ms	remaining: 556ms
# 27:	learn: 0.6807502	total: 102ms	remaining: 554ms
# 28:	learn: 0.6801165	total: 106ms	remaining: 552ms
# 29:	learn: 0.6798508	total: 110ms	remaining: 549ms
# 30:	learn: 0.6796055	total: 112ms	remaining: 540ms
# 31:	learn: 0.6792876	total: 116ms	remaining: 536ms
# 32:	learn: 0.6787626	total: 120ms	remaining: 533ms
# 33:	learn: 0.6783179	total: 123ms	remaining: 529ms
# 34:	learn: 0.6778754	total: 127ms	remaining: 526ms
# 35:	learn: 0.6775538	total: 130ms	remaining: 521ms
# 36:	learn: 0.6773626	total: 134ms	remaining: 517ms
# 37:	learn: 0.6770217	total: 137ms	remaining: 513ms
# 38:	learn: 0.6767171	total: 141ms	remaining: 509ms
# 39:	learn: 0.6764305	total: 145ms	remaining: 506ms
# 40:	learn: 0.6760978	total: 148ms	remaining: 502ms
# 41:	learn: 0.6757820	total: 152ms	remaining: 499ms
# 42:	learn: 0.6753925	total: 156ms	remaining: 496ms
# 43:	learn: 0.6750504	total: 160ms	remaining: 493ms
# 44:	learn: 0.6746310	total: 163ms	remaining: 490ms
# 45:	learn: 0.6742445	total: 167ms	remaining: 485ms
# 46:	learn: 0.6739955	total: 170ms	remaining: 481ms
# 47:	learn: 0.6734954	total: 174ms	remaining: 477ms
# 48:	learn: 0.6732335	total: 177ms	remaining: 473ms
# 49:	learn: 0.6730504	total: 180ms	remaining: 468ms
# 50:	learn: 0.6727875	total: 184ms	remaining: 466ms
# 51:	learn: 0.6724465	total: 188ms	remaining: 463ms
# 52:	learn: 0.6721803	total: 191ms	remaining: 459ms
# 53:	learn: 0.6719201	total: 195ms	remaining: 456ms
# 54:	learn: 0.6715899	total: 199ms	remaining: 452ms
# 55:	learn: 0.6713627	total: 202ms	remaining: 447ms
# 56:	learn: 0.6710532	total: 205ms	remaining: 443ms
# 57:	learn: 0.6707872	total: 209ms	remaining: 440ms
# 58:	learn: 0.6705471	total: 212ms	remaining: 435ms
# 59:	learn: 0.6701041	total: 216ms	remaining: 432ms
# 60:	learn: 0.6697632	total: 219ms	remaining: 428ms
# 61:	learn: 0.6693973	total: 222ms	remaining: 423ms
# 62:	learn: 0.6691564	total: 226ms	remaining: 420ms
# 63:	learn: 0.6688889	total: 230ms	remaining: 416ms
# 64:	learn: 0.6686956	total: 233ms	remaining: 412ms
# 65:	learn: 0.6684030	total: 236ms	remaining: 408ms
# 66:	learn: 0.6679987	total: 239ms	remaining: 403ms
# 67:	learn: 0.6676780	total: 243ms	remaining: 400ms
# 68:	learn: 0.6674928	total: 246ms	remaining: 396ms
# 69:	learn: 0.6673466	total: 249ms	remaining: 391ms
# 70:	learn: 0.6671160	total: 252ms	remaining: 387ms
# 71:	learn: 0.6668745	total: 255ms	remaining: 383ms
# 72:	learn: 0.6666794	total: 259ms	remaining: 380ms
# 73:	learn: 0.6662857	total: 262ms	remaining: 376ms
# 74:	learn: 0.6659873	total: 266ms	remaining: 372ms
# 75:	learn: 0.6657757	total: 269ms	remaining: 368ms
# 76:	learn: 0.6654969	total: 272ms	remaining: 364ms
# 77:	learn: 0.6652947	total: 276ms	remaining: 361ms
# 78:	learn: 0.6651207	total: 280ms	remaining: 357ms
# 79:	learn: 0.6648462	total: 283ms	remaining: 354ms
# 80:	learn: 0.6647153	total: 286ms	remaining: 349ms
# 81:	learn: 0.6645473	total: 289ms	remaining: 345ms
# 82:	learn: 0.6643778	total: 292ms	remaining: 341ms
# 83:	learn: 0.6641355	total: 295ms	remaining: 338ms
# 84:	learn: 0.6638856	total: 299ms	remaining: 334ms
# 85:	learn: 0.6635340	total: 302ms	remaining: 330ms
# 86:	learn: 0.6633118	total: 305ms	remaining: 326ms
# 87:	learn: 0.6630712	total: 309ms	remaining: 324ms
# 88:	learn: 0.6628121	total: 313ms	remaining: 320ms
# 89:	learn: 0.6624149	total: 316ms	remaining: 316ms
# 90:	learn: 0.6622085	total: 319ms	remaining: 312ms
# 91:	learn: 0.6619510	total: 322ms	remaining: 308ms
# 92:	learn: 0.6617506	total: 326ms	remaining: 305ms
# 93:	learn: 0.6614341	total: 329ms	remaining: 301ms
# 94:	learn: 0.6611723	total: 332ms	remaining: 297ms
# 95:	learn: 0.6609930	total: 336ms	remaining: 294ms
# 96:	learn: 0.6607964	total: 339ms	remaining: 290ms
# 97:	learn: 0.6606497	total: 343ms	remaining: 287ms
# 98:	learn: 0.6604699	total: 346ms	remaining: 283ms
# 99:	learn: 0.6603423	total: 350ms	remaining: 280ms
# 100:	learn: 0.6601584	total: 353ms	remaining: 276ms
# 101:	learn: 0.6599429	total: 356ms	remaining: 272ms
# 102:	learn: 0.6596989	total: 360ms	remaining: 269ms
# 103:	learn: 0.6594726	total: 363ms	remaining: 265ms
# 104:	learn: 0.6593594	total: 367ms	remaining: 262ms
# 105:	learn: 0.6591128	total: 371ms	remaining: 259ms
# 106:	learn: 0.6587976	total: 374ms	remaining: 255ms
# 107:	learn: 0.6586267	total: 378ms	remaining: 252ms
# 108:	learn: 0.6584666	total: 381ms	remaining: 248ms
# 109:	learn: 0.6583657	total: 384ms	remaining: 244ms
# 110:	learn: 0.6582436	total: 387ms	remaining: 241ms
# 111:	learn: 0.6580664	total: 391ms	remaining: 237ms
# 112:	learn: 0.6578046	total: 394ms	remaining: 234ms
# 113:	learn: 0.6576382	total: 398ms	remaining: 230ms
# 114:	learn: 0.6575065	total: 401ms	remaining: 227ms
# 115:	learn: 0.6573092	total: 404ms	remaining: 223ms
# 116:	learn: 0.6570234	total: 408ms	remaining: 220ms
# 117:	learn: 0.6567870	total: 411ms	remaining: 216ms
# 118:	learn: 0.6565096	total: 415ms	remaining: 213ms
# 119:	learn: 0.6563663	total: 418ms	remaining: 209ms
# 120:	learn: 0.6561460	total: 421ms	remaining: 205ms
# 121:	learn: 0.6559366	total: 424ms	remaining: 202ms
# 122:	learn: 0.6557964	total: 428ms	remaining: 198ms
# 123:	learn: 0.6555893	total: 431ms	remaining: 194ms
# 124:	learn: 0.6554284	total: 434ms	remaining: 191ms
# 125:	learn: 0.6550967	total: 437ms	remaining: 187ms
# 126:	learn: 0.6548864	total: 441ms	remaining: 184ms
# 127:	learn: 0.6547655	total: 444ms	remaining: 180ms
# 128:	learn: 0.6546059	total: 448ms	remaining: 177ms
# 129:	learn: 0.6543361	total: 451ms	remaining: 174ms
# 130:	learn: 0.6541062	total: 455ms	remaining: 170ms
# 131:	learn: 0.6539226	total: 458ms	remaining: 167ms
# 132:	learn: 0.6537863	total: 461ms	remaining: 163ms
# 133:	learn: 0.6536855	total: 465ms	remaining: 160ms
# 134:	learn: 0.6535240	total: 468ms	remaining: 156ms
# 135:	learn: 0.6533575	total: 471ms	remaining: 153ms
# 136:	learn: 0.6532061	total: 475ms	remaining: 149ms
# 137:	learn: 0.6530980	total: 478ms	remaining: 146ms
# 138:	learn: 0.6529294	total: 482ms	remaining: 142ms
# 139:	learn: 0.6527715	total: 485ms	remaining: 139ms
# 140:	learn: 0.6526563	total: 488ms	remaining: 135ms
# 141:	learn: 0.6525193	total: 491ms	remaining: 131ms
# 142:	learn: 0.6524331	total: 495ms	remaining: 128ms
# 143:	learn: 0.6522805	total: 509ms	remaining: 127ms
# 144:	learn: 0.6521971	total: 513ms	remaining: 124ms
# 145:	learn: 0.6520021	total: 516ms	remaining: 120ms
# 146:	learn: 0.6518383	total: 519ms	remaining: 117ms
# 147:	learn: 0.6516620	total: 523ms	remaining: 113ms
# 148:	learn: 0.6515018	total: 526ms	remaining: 110ms
# 149:	learn: 0.6513414	total: 529ms	remaining: 106ms
# 150:	learn: 0.6511590	total: 533ms	remaining: 102ms
# 151:	learn: 0.6509607	total: 536ms	remaining: 98.8ms
# 152:	learn: 0.6508149	total: 540ms	remaining: 95.3ms
# 153:	learn: 0.6506388	total: 543ms	remaining: 91.7ms
# 154:	learn: 0.6503721	total: 547ms	remaining: 88.2ms
# 155:	learn: 0.6501382	total: 550ms	remaining: 84.6ms
# 156:	learn: 0.6499885	total: 553ms	remaining: 81ms
# 157:	learn: 0.6498959	total: 556ms	remaining: 77.5ms
# 158:	learn: 0.6497499	total: 559ms	remaining: 73.9ms
# 159:	learn: 0.6496076	total: 562ms	remaining: 70.3ms
# 160:	learn: 0.6495142	total: 566ms	remaining: 66.7ms
# 161:	learn: 0.6494076	total: 568ms	remaining: 63.2ms
# 162:	learn: 0.6493135	total: 571ms	remaining: 59.6ms
# 163:	learn: 0.6492217	total: 575ms	remaining: 56.1ms
# 164:	learn: 0.6491182	total: 577ms	remaining: 52.5ms
# 165:	learn: 0.6489025	total: 580ms	remaining: 48.9ms
# 166:	learn: 0.6487756	total: 583ms	remaining: 45.4ms
# 167:	learn: 0.6486428	total: 586ms	remaining: 41.9ms
# 168:	learn: 0.6485357	total: 589ms	remaining: 38.4ms
# 169:	learn: 0.6484392	total: 592ms	remaining: 34.8ms
# 170:	learn: 0.6483055	total: 595ms	remaining: 31.3ms
# 171:	learn: 0.6481987	total: 598ms	remaining: 27.8ms
# 172:	learn: 0.6480296	total: 601ms	remaining: 24.3ms
# 173:	learn: 0.6479611	total: 604ms	remaining: 20.8ms
# 174:	learn: 0.6478407	total: 607ms	remaining: 17.3ms
# 175:	learn: 0.6476764	total: 610ms	remaining: 13.9ms
# 176:	learn: 0.6475607	total: 613ms	remaining: 10.4ms
# 177:	learn: 0.6474705	total: 616ms	remaining: 6.92ms
# 178:	learn: 0.6473937	total: 619ms	remaining: 3.46ms
# 179:	learn: 0.6472963	total: 622ms	remaining: 0us

# %%
ensemble_pred
# Out:
# array(['AbNormal', 'AbNormal', 'AbNormal', ..., 'Normal', 'AbNormal',
#        'Normal'], dtype=object)

# %% [markdown]
# ### 제출 파일 작성

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["target"] = ensemble_pred

# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 3
#       1 # 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
#       2 df_sub = pd.read_csv("submission.csv")
# ----> 3 df_sub["target"] = ensemble_pred
#       5 # 제출 파일 저장
#       6 df_sub.to_csv("submission.csv", index=False)
#
# File c:\Users\jy173\anaconda3\Lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File c:\Users\jy173\anaconda3\Lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
#    4178         and value.ndim == 1
#    4179         and not is_extension_array_dtype(value)
#    4180     ):
#    4181         # broadcast across multiple columns if necessary
#    4182         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Users\jy173\anaconda3\Lib\site-packages\pandas\core\frame.py:4915, in DataFrame._sanitize_column(self, value)
#    4912     return _reindex_for_setitem(Series(value), self.index)
#    4914 if is_list_like(value):
# -> 4915     com.require_length_match(value, self.index)
#    4916 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File c:\Users\jy173\anaconda3\Lib\site-packages\pandas\core\common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (4700) does not match length of index (17361)

# %% [markdown]
# **우측 상단의 제출 버튼을 클릭해 결과를 확인하세요**
